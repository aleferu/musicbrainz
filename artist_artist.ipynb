# %% [markdown]
# # Artist-Artist relationships
#
# By Alejandro Fernández Sánchez

# %% [markdown]
# ## Setting up the connection

# %%
# Just in case you're the host and it's not already started
# !service postgresql start

# %%
# Imports
import psycopg2
import pandas as pd
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv
import json
load_dotenv()
# Out:
# True

# %%
DB_NAME = os.getenv("DB_NAME")
DB_HOST = os.getenv("DB_HOST")
DB_USER = os.getenv("DB_USER")
DB_PASS = os.getenv("DB_PASS")
DB_PORT = os.getenv("DB_PORT")

# %%
# Establishing a connection via postgre's python driver
conn = psycopg2.connect(
    database=DB_NAME,
    host=DB_HOST,
    user=DB_USER,
    password=DB_PASS,
    port=DB_PORT
)
conn
# Out:
# <connection object at 0x7ff39cef6980; dsn: 'user=musicbrainz password=xxx dbname=musicbrainz_db host=localhost port=5432', closed: 0>

# %%
cursor = conn.cursor()  # Helps with querying without memory allocation
cursor
# Out:
# <cursor object at 0x7ff39ce0ef20; closed: 0>

# %%
# Helper function
def query_with_cursor(c, q, column_names=False, head=False):
    conn.rollback()  # This is needed if a previous query fails
    c.execute(q)
    if column_names:
        print([col[0] for col in c.description])
    count = 0
    for r in c:
        print(r)
        count += 1
        if head and count == 10:
            break

# %%
# Used for saving results to pandas dataframes
engine_url = f"postgresql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(engine_url)
engine
# Out:
# Engine(postgresql://musicbrainz:***@localhost:5432/musicbrainz_db)

# %% [markdown]
# ## Types of artists relationships

# %% [markdown]
# How many are there?

# %%
query_with_cursor(
    cursor,
    "SELECT COUNT(*) FROM l_artist_artist"
)
# Out:
# (671957,)

# %% [markdown]
# Seems like a fairly big number, let's check how they relate to each other.

# %%
query =\
"""
SELECT id, name, description, long_link_phrase
FROM link_type
WHERE entity_type0 = 'artist'
  AND entity_type1 = 'artist'
ORDER BY id
"""
pd.read_sql_query(query, engine)
# Out:
#       id                              name  \
# 0    102                     collaboration
# 1    103                    member of band
# 2    104               supporting musician
# 3    105  instrumental supporting musician
# 4    106             musical relationships
# 5    107         vocal supporting musician
# 6    108                         is person
# 7    109                            parent
# 8    110                           sibling
# 9    111                           married
# 10   112                     involved with
# 11   113             personal relationship
# 12   292                       voice actor
# 13   305                conductor position
# 14   722                          subgroup
# 15   728                           tribute
# 16   847                           teacher
# 17   855             composer-in-residence
# 18   895                           founder
# 19   965                 artistic director
# 20   973                       named after
# 21  1079                     artist rename
#
#                                           description  \
# 0   This is used to specify that an <a href="/doc/...
# 1     This indicates a person is a member of a group.
# 2   Indicates an artist doing long-time instrument...
# 3   Indicates a musician doing long-time instrumen...
# 4
# 5   Indicates a musician doing long-time vocal sup...
# 6   This links an artist's performance name (a sta...
# 7              Indicates a parent-child relationship.
# 8      This links two siblings (brothers or sisters).
# 9                This links artists who were married.
# 10  Indicates that two persons were romantically i...
# 11
# 12  This links an (fictional) artist to the person...
# 13  This indicates that a person is, or was, a con...
# 14  This links a subgroup to the group from which ...
# 15  This relationship specifies that an artist is ...
# 16  This relationship indicates that a person was ...
# 17  This links a group (often an orchestra) to a c...
# 18  This indicates an artist (generally a person) ...
# 19  This indicates that a person is, or was, the a...
# 20  This indicates the artist that inspired this a...
# 21  This describes a situation where an artist (ge...
#
#                                      long_link_phrase
# 0   collaborated {minor:minorly} {additional:addit...
# 1   is/was {additional:an|a} {additional} {origina...
# 2                      is/was a supporting artist for
# 3                   does/did {instrument} support for
# 4                                musical relationship
# 5               does/did {vocal:%|vocals} support for
# 6                                         performs as
# 7                              is the {step}parent of
# 8                       has {half:half-}{step}sibling
# 9                                   is/was married to
# 10                  is/was romantically involved with
# 11                              personal relationship
# 12                             performed the voice of
# 13  is/was {assistant:an|a} {assistant} {principal...
# 14                               is/was a subgroup of
# 15                                    is a tribute to
# 16                                             taught
# 17                     was a composer-in-residence at
# 18                                            founded
# 19                       is/was artistic director for
# 20                                     is named after
# 21                                   was renamed into

# %% [markdown]
# It seems like we have 22 possible relationships. They are all important, but there are three that differ from the rest.
#
# Ids 1079 and 108. As I understand them, we should only have one entity of the same artist in the final CSVs. I'm going to store all occurrences of an artist in a list and stay with the most used instance.
#
# Id 292. This relationship links a voice actor with their character.

# %% [markdown]
# ## Artist dataset
#
# We now have all the information needed to tackle the task of generating an artist dataset. Using relationships 108, 292, 1079 we'll create a list of known ids and names for each artist and store them following the JSONL convention.
#
# The first subtask is to find pairs of entities that represents the same artist.

# %%
query =\
f"""
SELECT a0.id AS a0_id, a0.name AS a0_name, a1.id AS a1_id, a1.name AS a1_name
FROM l_artist_artist laa
JOIN artist a0 ON a0.id = laa.entity0
JOIN artist a1 ON a1.id = laa.entity1
WHERE laa.link IN (
    SELECT id
    FROM link
    WHERE link_type IN (1079, 108, 292)
)
"""
pairs = pd.read_sql_query(query, engine, dtype=str)
pairs.drop_duplicates(inplace=True)
pairs
# Out:
#          a0_id               a0_name    a1_id          a1_name
# 0       510355             Tom Salta   510353       Atlas Plug
# 1       515380         Sara Nicholas   512604  DJ Ginger Snapp
# 2       805193          Péter Takács   182397             Deto
# 3      1816108         Alex Bilowitz  1303285        Alex Bilo
# 4       366859  Tobias Lützenkirchen   134438              LXR
# ...        ...                   ...      ...              ...
# 71552  2733295         Jan Pettersen  2733293             Jinx
# 71553   107069           Chris Cowie  2516613                Q
# 71554   308020          Michael Baur  2733227          Code-22
# 71555  1823042           glass beach  2733316    glass beach 2
# 71556   156470            Ed Starink   747864     A Close Call
#
# [71508 rows x 4 columns]

# %% [markdown]
# We now separate each artist in their own list of entities (id and name).

# %%
# I've iterated though some algorithms that I came up with and this is the fastest one (that works)
# This algorithm groups all the different (same) artists in a list
seen_dict = dict()
artists_lists = list()
last_idx = -1
for _, row in pairs.iterrows():
    artist0 = {"id": row["a0_id"], "name": row["a0_name"]}
    artist1 = {"id": row["a1_id"], "name": row["a1_name"]}
    if artist0["id"] in seen_dict:
        if artist1["id"] in seen_dict:
            continue
        artist0_idx = seen_dict[artist0["id"]]
        artists_lists[artist0_idx].append(artist1)
        seen_dict[artist1["id"]] = artist0_idx
    elif artist1["id"] in seen_dict:
        artist1_idx = seen_dict[artist1["id"]]
        artists_lists[artist1_idx].append(artist0)
        seen_dict[artist0["id"]] = artist1_idx
    else:
        last_idx += 1
        artists_lists.append([artist0, artist1])
        seen_dict[artist0["id"]] = last_idx
        seen_dict[artist1["id"]] = last_idx
artists_lists[:5]
# Out:
# [[{'id': '510355', 'name': 'Tom Salta'},
#   {'id': '510353', 'name': 'Atlas Plug'}],
#  [{'id': '515380', 'name': 'Sara Nicholas'},
#   {'id': '512604', 'name': 'DJ Ginger Snapp'}],
#  [{'id': '805193', 'name': 'Péter Takács'}, {'id': '182397', 'name': 'Deto'}],
#  [{'id': '1816108', 'name': 'Alex Bilowitz'},
#   {'id': '1303285', 'name': 'Alex Bilo'}],
#  [{'id': '366859', 'name': 'Tobias Lützenkirchen'},
#   {'id': '134438', 'name': 'LXR'},
#   {'id': '131031', 'name': 'Karosa'},
#   {'id': '121353', 'name': 'Richthoven'},
#   {'id': '408293', 'name': 'L.Y.T.Z.'},
#   {'id': '258876', 'name': 'Lützenkirchen'},
#   {'id': '411300', 'name': 'Lu Tracks'},
#   {'id': '165609', 'name': '7-7-0'},
#   {'id': '159973', 'name': 'Toby Lee Connor'},
#   {'id': '690598', 'name': 'Paratopic'}]]

# %% [markdown]
# We now need to find which artist instance is the most common. For that we're going to be using the `releases_no_va.csv` dataset.

# %%
releases = pd.read_csv("releases_no_va.csv", dtype=str)
releases.fillna("", inplace=True)
releases
# Out:
#                                              name        date artist_credit  \
# 0                                               !  2020-08-06        119635
# 1                                            Sabr  2009-02-16       2094632
# 2                                  Sabr Aur Shukr  2023-09-08        351688
# 3                              Sabra Shatila 1982  2019-12-28       1288322
# 4                     Sabrana Djela 1976. - 1987.  2019-03-28        414860
# ...                                           ...         ...           ...
# 2841551  Glorious Percussion / In tempus praesens  2011-10-28       1085468
# 2841552                           Glow of Benares  2017-11-24       2962164
# 2841553                                Glowing Up  2021-06-11       3222555
# 2841554             Gloria and Other Choral Music  1988-12-28       2062383
# 2841555                                       잊지마  2015-01-03       1438016
#
#         artist_count    a0_id                     a0_name    a1_id  \
# 0                  1   119635                 Kevin Drumm
# 1                  1  1450753              Shahram Solati
# 2                  1   351688            Shekhar Ravjiani
# 3                  1  1096452           Geography of Hell
# 4                  1   414860                       Paraf
# ...              ...      ...                         ...      ...
# 2841551            5   947108  Luzerner Sinfonieorchester   947105
# 2841552            5  1496607            Abhijit Banerjee  1058331
# 2841553            5  2290023                        TUSO  2290022
# 2841554            5   551005                  Donna Deam   476955
# 2841555            5  1205355                       Loota  1205354
#
#                          a1_name    a2_id                a2_name    a3_id  \
# 0
# 1
# 2
# 3
# 4
# ...                          ...      ...                    ...      ...
# 2841551      Glorious Percussion   538910          Vadim Gluzman   420382
# 2841552   Randers Kammerorkester   494877           Kala Ramnath   310652
# 2841553                    Tudor  2118382                 Milwin  1886127
# 2841554  City of London Sinfonia   129845  The Cambridge Singers    36433
# 2841555                JayAllDay  1205352              Keith Ape  1129217
#
#                        a3_name    a4_id                      a4_name
# 0
# 1
# 2
# 3
# 4
# ...                        ...      ...                          ...
# 2841551          Jonathan Nott   153732  София Асгатовна Губайдулина
# 2841552  Aarhus Jazz Orchestra    23800                  Lars Møller
# 2841553               Discrete  1184231               Sofia Karlberg
# 2841554            John Rutter    30462              Francis Poulenc
# 2841555                   KOHH  1033122                      Okasian
#
# [2841556 rows x 14 columns]

# %%
id_columns = [f"a{i}_id" for i in range(5)]
artist_freqs = (releases[id_columns].melt().groupby(by=["value"]).count()).to_dict(index="value")["variable"]
artist_freqs
# Out:
# {'': 10909872,
#  '10': 6,
#  '1000': 44,
#  '1000007': 1,
#  '1000008': 2,
#  '1000017': 1,
#  '100002': 1,
#  '1000025': 1,
#  '100003': 1,
#  '100004': 4,
#  '1000049': 1,
#  '100005': 2,
#  '1000058': 1,
#  '1000060': 3,
#  '1000067': 7,
#  '1000068': 2,
#  '1000073': 1,
#  '1000077': 1,
#  '1000078': 1,
#  '1000079': 1,
#  '1000080': 16,
#  '1000081': 3,
#  '1000082': 3,
#  '1000083': 1,
#  '1000085': 2,
#  '100009': 1,
#  '1000095': 1,
#  '1000096': 2,
#  '1000107': 1,
#  '1000112': 1,
#  '100012': 15,
#  '1000120': 2,
#  '1000121': 1,
#  '1000130': 3,
#  '1000131': 1,
#  '1000135': 12,
#  '1000138': 6,
#  '100014': 1,
#  '1000143': 3,
#  '1000144': 1,
#  '1000146': 1,
#  '1000147': 2,
#  '1000148': 1,
#  '1000150': 1,
#  '1000151': 1,
#  '1000154': 1,
#  '1000155': 2,
#  '1000156': 1,
#  '1000157': 1,
#  '1000158': 3,
#  '1000159': 2,
#  '1000161': 4,
#  '1000164': 1,
#  '1000167': 1,
#  '1000168': 3,
#  '100017': 3,
#  '1000170': 1,
#  '1000171': 11,
#  '100018': 2,
#  '1000182': 1,
#  '1000187': 1,
#  '1000188': 4,
#  '1000196': 3,
#  '1000199': 2,
#  '100020': 4,
#  '1000200': 1,
#  '1000202': 5,
#  '1000204': 4,
#  '1000205': 1,
#  '1000206': 2,
#  '1000207': 4,
#  '1000208': 1,
#  '100021': 4,
#  '1000210': 5,
#  '1000213': 3,
#  '1000214': 4,
#  '1000218': 1,
#  '1000222': 1,
#  '1000223': 1,
#  '1000224': 1,
#  '1000232': 2,
#  '1000234': 1,
#  '1000235': 1,
#  '1000239': 1,
#  '100025': 6,
#  '1000250': 1,
#  '1000251': 3,
#  '1000252': 4,
#  '1000253': 1,
#  '1000254': 1,
#  '1000256': 1,
#  '1000259': 1,
#  '100026': 1,
#  '1000260': 1,
#  '1000261': 1,
#  '1000272': 5,
#  '100028': 10,
#  '1000287': 1,
#  '1000291': 1,
#  '1000294': 2,
#  '1000308': 2,
#  '1000317': 1,
#  '1000318': 7,
#  '1000323': 3,
#  '100033': 1,
#  '1000332': 9,
#  '1000333': 1,
#  '1000334': 1,
#  '1000335': 1,
#  '1000338': 3,
#  '1000339': 1,
#  '100034': 20,
#  '1000340': 5,
#  '1000343': 8,
#  '1000347': 5,
#  '1000349': 3,
#  '100035': 9,
#  '1000350': 9,
#  '1000355': 1,
#  '1000378': 8,
#  '100038': 1,
#  '1000389': 1,
#  '100039': 1,
#  '100040': 5,
#  '1000404': 1,
#  '100041': 1,
#  '1000410': 1,
#  '1000411': 1,
#  '1000416': 1,
#  '1000429': 1,
#  '1000431': 1,
#  '1000433': 6,
#  '1000434': 1,
#  '1000436': 1,
#  '1000439': 1,
#  '100044': 1,
#  '1000440': 1,
#  '1000441': 1,
#  '1000442': 1,
#  '1000443': 3,
#  '1000444': 1,
#  '1000445': 1,
#  '1000446': 1,
#  '1000447': 1,
#  '1000448': 1,
#  '1000450': 1,
#  '1000451': 1,
#  '1000453': 1,
#  '1000454': 1,
#  '1000455': 5,
#  '1000457': 2,
#  '1000458': 3,
#  '1000459': 1,
#  '100046': 1,
#  '1000463': 24,
#  '1000465': 1,
#  '1000466': 23,
#  '100047': 4,
#  '1000478': 1,
#  '1000481': 6,
#  '1000483': 21,
#  '100049': 1,
#  '1000491': 1,
#  '1000493': 2,
#  '1000497': 5,
#  '1000498': 4,
#  '100050': 2,
#  '1000503': 17,
#  '1000515': 2,
#  '1000516': 6,
#  '1000517': 1,
#  '1000519': 2,
#  '1000523': 1,
#  '1000524': 10,
#  '1000535': 1,
#  '100054': 1,
#  '1000550': 1,
#  '1000552': 1,
#  '1000556': 1,
#  '1000558': 4,
#  '1000560': 1,
#  '1000561': 3,
#  '1000563': 7,
#  '1000567': 1,
#  '1000574': 6,
#  '1000576': 1,
#  '1000579': 1,
#  '100058': 65,
#  '1000580': 2,
#  '1000586': 1,
#  '100060': 1,
#  '1000609': 1,
#  '1000618': 2,
#  '1000619': 5,
#  '100062': 3,
#  '1000621': 2,
#  '1000622': 2,
#  '1000624': 1,
#  '1000625': 26,
#  '1000626': 5,
#  '1000627': 3,
#  '1000629': 4,
#  '1000630': 1,
#  '1000631': 1,
#  '1000632': 1,
#  '1000636': 1,
#  '1000639': 13,
#  '1000640': 18,
#  '1000641': 20,
#  '1000643': 1,
#  '1000644': 5,
#  '1000647': 1,
#  '1000648': 4,
#  '1000649': 1,
#  '100065': 1,
#  '1000651': 1,
#  '1000652': 2,
#  '1000653': 1,
#  '1000654': 8,
#  '1000655': 1,
#  '1000656': 1,
#  '1000658': 2,
#  '1000661': 1,
#  '1000662': 1,
#  '1000663': 2,
#  '1000664': 3,
#  '1000665': 3,
#  '1000668': 1,
#  '1000671': 3,
#  '1000672': 1,
#  '1000673': 7,
#  '1000676': 1,
#  '1000677': 4,
#  '1000678': 1,
#  '100068': 4,
#  '1000680': 5,
#  '1000681': 1,
#  '1000682': 1,
#  '1000683': 1,
#  '1000684': 1,
#  '1000685': 9,
#  '1000686': 1,
#  '100069': 1,
#  '1000691': 1,
#  '1000695': 1,
#  '1000697': 1,
#  '1000699': 1,
#  '10007': 30,
#  '1000701': 4,
#  '1000702': 1,
#  '1000703': 1,
#  '1000708': 6,
#  '1000712': 1,
#  '1000713': 8,
#  '1000723': 8,
#  '1000728': 10,
#  '1000729': 2,
#  '100073': 1,
#  '1000732': 2,
#  '1000734': 1,
#  '1000735': 2,
#  '1000739': 10,
#  '1000741': 1,
#  '1000743': 3,
#  '1000744': 1,
#  '1000745': 1,
#  '1000746': 1,
#  '1000747': 1,
#  '1000756': 1,
#  '1000758': 2,
#  '1000759': 4,
#  '1000760': 1,
#  '1000762': 5,
#  '1000764': 3,
#  '100077': 2,
#  '1000772': 1,
#  '1000774': 1,
#  '1000776': 2,
#  '1000778': 2,
#  '100078': 2,
#  '1000789': 1,
#  '1000790': 11,
#  '1000793': 2,
#  '1000795': 2,
#  '1000798': 1,
#  '1000799': 1,
#  '100080': 5,
#  '1000800': 4,
#  '1000801': 1,
#  '1000802': 4,
#  '1000806': 1,
#  '1000808': 5,
#  '1000819': 2,
#  '1000820': 37,
#  '1000824': 3,
#  '100083': 1,
#  '1000830': 1,
#  '100085': 1,
#  '1000850': 1,
#  '100086': 2,
#  '1000866': 11,
#  '1000867': 1,
#  '100087': 39,
#  '1000870': 2,
#  '1000871': 1,
#  '1000877': 10,
#  '1000878': 1,
#  '1000879': 2,
#  '100088': 1,
#  '1000884': 1,
#  '1000886': 1,
#  '1000895': 7,
#  '1000900': 4,
#  '1000901': 1,
#  '1000908': 4,
#  '1000909': 1,
#  '1000911': 4,
#  '1000912': 1,
#  '1000913': 2,
#  '100092': 5,
#  '1000921': 1,
#  '1000924': 2,
#  '1000925': 1,
#  '1000926': 2,
#  '1000927': 3,
#  '1000928': 4,
#  '1000933': 1,
#  '1000940': 11,
#  '1000941': 1,
#  '1000944': 4,
#  '1000945': 1,
#  '1000946': 7,
#  '1000948': 4,
#  '1000949': 1,
#  '1000950': 1,
#  '1000952': 1,
#  '1000960': 1,
#  '1000961': 1,
#  '1000967': 1,
#  '1000983': 1,
#  '1000986': 4,
#  '1000987': 1,
#  '1000988': 1,
#  '1000989': 2,
#  '100099': 5,
#  '1000990': 5,
#  '1000991': 6,
#  '1000992': 1,
#  '1000993': 2,
#  '1000994': 2,
#  '1000995': 1,
#  '1000996': 3,
#  '1001': 59,
#  '1001000': 3,
#  '1001005': 3,
#  '1001006': 3,
#  '1001014': 3,
#  '1001018': 1,
#  '1001019': 5,
#  '1001020': 2,
#  '1001026': 1,
#  '1001034': 1,
#  '100104': 20,
#  '1001054': 1,
#  '1001055': 1,
#  '1001078': 1,
#  '1001083': 2,
#  '1001087': 3,
#  '1001098': 6,
#  '1001102': 2,
#  '1001107': 1,
#  '1001109': 1,
#  '1001114': 3,
#  '1001124': 6,
#  '1001125': 7,
#  '1001127': 3,
#  '1001130': 17,
#  '1001133': 1,
#  '1001135': 1,
#  '1001136': 17,
#  '1001137': 1,
#  '1001139': 1,
#  '1001150': 10,
#  '1001151': 2,
#  '1001152': 1,
#  '1001153': 1,
#  '1001155': 3,
#  '1001169': 5,
#  '1001185': 16,
#  '1001189': 4,
#  '1001190': 26,
#  '1001195': 1,
#  '100120': 18,
#  '1001205': 2,
#  '100121': 2,
#  '1001210': 5,
#  '1001212': 4,
#  '1001214': 1,
#  '1001216': 1,
#  '100122': 3,
#  '1001220': 1,
#  '1001221': 2,
#  '1001223': 3,
#  '1001224': 1,
#  '1001229': 5,
#  '100123': 35,
#  '1001232': 1,
#  '1001235': 1,
#  '1001241': 2,
#  '1001251': 2,
#  '1001253': 3,
#  '1001259': 1,
#  '1001266': 1,
#  '1001269': 1,
#  '100127': 1,
#  '1001279': 1,
#  '1001280': 1,
#  '1001287': 1,
#  '1001288': 2,
#  '100130': 1,
#  '1001306': 4,
#  '1001308': 2,
#  '100131': 3,
#  '1001319': 9,
#  '1001324': 7,
#  '1001327': 7,
#  '1001329': 1,
#  '1001330': 1,
#  '1001332': 11,
#  '1001337': 5,
#  '1001344': 1,
#  '1001350': 1,
#  '1001355': 5,
#  '1001359': 1,
#  '1001361': 1,
#  '1001362': 2,
#  '1001369': 1,
#  '100137': 2,
#  '1001373': 1,
#  '1001374': 1,
#  '1001375': 2,
#  '1001376': 1,
#  '1001377': 2,
#  '1001378': 1,
#  '1001379': 1,
#  '100138': 2,
#  '1001380': 1,
#  '1001381': 1,
#  '1001382': 1,
#  '1001383': 2,
#  '1001384': 1,
#  '1001385': 1,
#  '1001386': 2,
#  '1001387': 1,
#  '1001388': 1,
#  '1001389': 1,
#  '1001390': 6,
#  '1001391': 1,
#  '1001401': 1,
#  '1001409': 6,
#  '1001418': 2,
#  '1001429': 3,
#  '100143': 1,
#  '1001437': 4,
#  '1001440': 1,
#  '1001442': 1,
#  '1001443': 1,
#  '1001445': 1,
#  '1001449': 1,
#  '1001450': 5,
#  '1001451': 1,
#  '1001454': 1,
#  '1001455': 1,
#  '1001461': 1,
#  '1001464': 2,
#  '1001465': 1,
#  '1001468': 2,
#  '1001470': 1,
#  '1001475': 3,
#  '1001476': 1,
#  '1001478': 3,
#  '100148': 2,
#  '1001480': 3,
#  '1001482': 1,
#  '1001484': 1,
#  '1001485': 1,
#  '1001486': 1,
#  '1001489': 1,
#  '1001491': 1,
#  '1001493': 7,
#  '1001497': 1,
#  '1001499': 1,
#  '10015': 7,
#  '1001505': 1,
#  '1001507': 8,
#  '100151': 3,
#  '1001511': 2,
#  '1001513': 13,
#  '1001515': 6,
#  '100152': 1,
#  '1001520': 4,
#  '1001521': 7,
#  '100153': 17,
#  '1001534': 1,
#  '100154': 123,
#  '1001543': 1,
#  '1001545': 1,
#  '1001546': 1,
#  '1001549': 1,
#  '100155': 6,
#  '1001551': 1,
#  '100158': 9,
#  '100159': 1,
#  '1001593': 35,
#  '1001596': 5,
#  '1001597': 1,
#  '100160': 2,
#  '1001606': 2,
#  '1001611': 2,
#  '1001613': 1,
#  '1001617': 6,
#  '1001621': 1,
#  '1001624': 1,
#  '1001625': 3,
#  '1001626': 1,
#  '100163': 3,
#  '1001634': 2,
#  '1001637': 1,
#  '100164': 1,
#  '1001641': 1,
#  '1001643': 36,
#  '1001645': 1,
#  '1001646': 1,
#  '1001655': 1,
#  '1001656': 1,
#  '100166': 9,
#  '1001662': 1,
#  '1001663': 2,
#  '1001666': 1,
#  '1001669': 1,
#  '1001671': 2,
#  '1001673': 4,
#  '1001675': 1,
#  '1001676': 6,
#  '100168': 1,
#  '1001684': 2,
#  '1001686': 2,
#  '1001687': 4,
#  '1001689': 1,
#  '100169': 35,
#  '1001690': 2,
#  '1001691': 1,
#  '1001694': 7,
#  '1001697': 6,
#  '1001698': 1,
#  '100170': 6,
#  '1001700': 1,
#  '1001702': 1,
#  '1001704': 11,
#  '1001705': 2,
#  '1001706': 1,
#  '100171': 4,
#  '1001714': 1,
#  '1001715': 6,
#  '1001719': 1,
#  '100172': 5,
#  '1001724': 1,
#  '1001725': 1,
#  '1001726': 1,
#  '1001727': 20,
#  '1001730': 1,
#  '1001734': 5,
#  '1001735': 2,
#  '1001737': 1,
#  '1001744': 2,
#  '1001746': 3,
#  '1001747': 1,
#  '1001748': 1,
#  '1001753': 2,
#  '1001760': 2,
#  '1001761': 2,
#  '100177': 5,
#  '1001773': 1,
#  '1001774': 4,
#  '1001776': 1,
#  '1001777': 1,
#  '1001778': 1,
#  '1001779': 3,
#  '1001780': 4,
#  '1001781': 8,
#  '1001782': 2,
#  '1001783': 3,
#  '1001788': 2,
#  '1001792': 1,
#  '1001801': 4,
#  '1001802': 3,
#  '1001810': 1,
#  '1001812': 2,
#  '1001813': 1,
#  '1001819': 1,
#  '1001821': 1,
#  '1001823': 3,
#  '1001829': 2,
#  '1001835': 8,
#  '100184': 6,
#  '1001840': 1,
#  '1001841': 1,
#  '1001853': 1,
#  '1001854': 4,
#  '1001865': 1,
#  '1001872': 1,
#  '1001878': 2,
#  '1001885': 10,
#  '1001900': 7,
#  '1001905': 18,
#  '1001906': 1,
#  '1001908': 1,
#  '1001911': 3,
#  '1001915': 1,
#  '1001916': 33,
#  '1001918': 3,
#  '1001924': 31,
#  '1001927': 18,
#  '1001928': 4,
#  '1001929': 5,
#  '1001931': 2,
#  '1001933': 14,
#  '1001938': 6,
#  '100194': 4,
#  '1001942': 4,
#  '1001943': 4,
#  '1001944': 2,
#  '1001946': 6,
#  '1001949': 27,
#  '1001951': 2,
#  '1001952': 2,
#  '1001953': 3,
#  '1001954': 3,
#  '1001958': 8,
#  '1001964': 1,
#  '1001965': 2,
#  '1001966': 6,
#  '1001967': 2,
#  '1001969': 4,
#  '100197': 2,
#  '1001975': 5,
#  '1001976': 1,
#  '1001977': 1,
#  '1001981': 2,
#  '1001982': 5,
#  '1001983': 3,
#  '100199': 19,
#  '1001994': 1,
#  '1001997': 1,
#  '100200': 8,
#  '1002002': 2,
#  '1002003': 1,
#  '1002007': 4,
#  '1002011': 1,
#  '1002016': 1,
#  '100202': 64,
#  '1002021': 1,
#  '1002024': 5,
#  '1002026': 4,
#  '1002030': 5,
#  '1002031': 1,
#  '1002037': 5,
#  '1002039': 1,
#  '100204': 5,
#  '1002040': 1,
#  '1002042': 2,
#  '1002043': 1,
#  '1002044': 2,
#  '1002050': 1,
#  '1002052': 1,
#  '1002053': 1,
#  '100206': 1,
#  '1002061': 1,
#  '1002062': 1,
#  '1002063': 18,
#  '1002064': 1,
#  '1002065': 2,
#  '1002066': 1,
#  '1002068': 1,
#  '1002069': 4,
#  '100207': 2,
#  '1002070': 1,
#  '1002073': 1,
#  '1002076': 3,
#  '1002077': 5,
#  '100208': 1,
#  '1002080': 4,
#  '1002081': 7,
#  '1002082': 1,
#  '1002084': 4,
#  '1002087': 2,
#  '1002088': 2,
#  '1002089': 7,
#  '100209': 1,
#  '1002097': 4,
#  '1002098': 2,
#  '1002102': 1,
#  '1002104': 1,
#  '1002108': 1,
#  '1002109': 1,
#  '1002113': 3,
#  '1002115': 1,
#  '1002116': 1,
#  '1002123': 3,
#  '1002124': 10,
#  '1002125': 2,
#  '1002127': 2,
#  '1002128': 3,
#  '1002131': 2,
#  '1002132': 4,
#  '1002138': 3,
#  '1002139': 1,
#  '100214': 6,
#  '1002140': 5,
#  '1002142': 2,
#  '1002144': 1,
#  '1002146': 3,
#  '1002148': 4,
#  '100215': 25,
#  '1002151': 1,
#  '1002153': 2,
#  '1002157': 1,
#  '100217': 7,
#  '1002175': 1,
#  '1002176': 3,
#  '1002178': 11,
#  '1002179': 4,
#  '100218': 4,
#  '1002181': 1,
#  '1002183': 1,
#  '1002185': 1,
#  '1002192': 1,
#  '100221': 11,
#  '1002214': 1,
#  '1002215': 19,
#  '1002230': 6,
#  '1002231': 2,
#  '1002232': 3,
#  '1002233': 6,
#  '1002234': 3,
#  '1002239': 1,
#  '100224': 3,
#  '1002240': 1,
#  '1002242': 3,
#  '1002243': 7,
#  '1002244': 1,
#  '1002246': 2,
#  '100225': 11,
#  '1002250': 1,
#  '1002251': 1,
#  '1002252': 1,
#  '1002253': 4,
#  '1002254': 3,
#  '1002255': 4,
#  '1002256': 2,
#  '1002260': 1,
#  '1002262': 1,
#  '1002274': 1,
#  '1002276': 1,
#  '1002284': 1,
#  '1002286': 1,
#  '1002291': 4,
#  '1002292': 3,
#  '1002293': 6,
#  '1002294': 1,
#  '100230': 4,
#  '100231': 2,
#  '1002313': 1,
#  '1002314': 4,
#  '1002315': 1,
#  '1002318': 1,
#  '1002321': 1,
#  '1002322': 1,
#  '1002323': 1,
#  '1002324': 3,
#  '1002325': 1,
#  '1002326': 2,
#  '1002327': 1,
#  '1002328': 1,
#  '1002331': 2,
#  '1002332': 1,
#  '1002333': 2,
#  '1002335': 1,
#  '1002336': 1,
#  '1002337': 1,
#  '1002338': 1,
#  '1002339': 3,
#  '100234': 4,
#  '1002340': 1,
#  '1002343': 3,
#  '1002344': 3,
#  '1002345': 3,
#  '1002347': 1,
#  '100235': 1,
#  '1002355': 6,
#  '1002357': 3,
#  '1002358': 2,
#  '1002360': 1,
#  '1002361': 9,
#  '1002364': 1,
#  '1002368': 1,
#  '1002372': 2,
#  '1002373': 35,
#  '1002374': 1,
#  '1002375': 1,
#  '1002376': 1,
#  '1002378': 5,
#  '1002380': 4,
#  '1002384': 1,
#  '1002385': 11,
#  '1002386': 1,
#  '1002387': 1,
#  '1002388': 4,
#  '1002389': 1,
#  '10024': 17,
#  '1002401': 1,
#  '1002402': 1,
#  '1002405': 1,
#  '1002406': 1,
#  '1002408': 1,
#  '1002409': 2,
#  '100241': 2,
#  '1002410': 9,
#  '1002415': 2,
#  '1002422': 1,
#  '1002431': 1,
#  '1002433': 1,
#  '1002434': 17,
#  '1002435': 1,
#  '1002436': 2,
#  '1002437': 3,
#  '1002438': 1,
#  '100244': 3,
#  '1002440': 2,
#  '1002441': 4,
#  '1002443': 7,
#  '1002444': 24,
#  '1002447': 1,
#  '1002448': 13,
#  '1002452': 1,
#  '1002454': 1,
#  '1002457': 18,
#  '1002458': 3,
#  '1002459': 3,
#  '100246': 1,
#  '1002462': 5,
#  '1002463': 2,
#  '1002465': 1,
#  '1002468': 1,
#  '1002474': 20,
#  '1002479': 1,
#  '1002481': 39,
#  '1002486': 1,
#  '1002493': 3,
#  '1002495': 3,
#  '10025': 177,
#  '1002502': 5,
#  '1002508': 1,
#  '1002509': 2,
#  '1002510': 2,
#  '1002514': 1,
#  '1002524': 1,
#  '1002532': 1,
#  '1002535': 2,
#  '1002536': 17,
#  '1002537': 1,
#  '1002538': 1,
#  '1002539': 1,
#  '100254': 2,
#  '1002541': 3,
#  '1002542': 1,
#  '1002543': 7,
#  '1002544': 2,
#  '1002546': 1,
#  '1002548': 1,
#  '1002549': 1,
#  '1002550': 1,
#  '1002553': 1,
#  '1002555': 10,
#  '1002556': 1,
#  '1002562': 1,
#  '1002565': 1,
#  '1002566': 1,
#  '1002572': 3,
#  '1002587': 1,
#  '1002588': 9,
#  '1002589': 6,
#  '1002590': 1,
#  '1002591': 1,
#  '1002594': 1,
#  '1002598': 1,
#  '1002599': 4,
#  '10026': 44,
#  '100260': 2,
#  '1002605': 1,
#  '1002608': 2,
#  '100261': 1,
#  '1002613': 1,
#  '1002615': 1,
#  '1002616': 1,
#  '1002621': 1,
#  '1002623': 2,
#  '1002635': 1,
#  '1002636': 1,
#  '1002637': 3,
#  '1002638': 1,
#  '1002640': 2,
#  '1002641': 1,
#  '1002647': 1,
#  '100265': 5,
#  '1002650': 1,
#  '1002651': 6,
#  '1002663': 1,
#  '1002671': 1,
#  '1002672': 23,
#  '1002673': 13,
#  '1002674': 1,
#  '1002676': 1,
#  '1002677': 2,
#  '1002678': 2,
#  '1002679': 1,
#  '1002680': 1,
#  '1002691': 1,
#  '1002693': 4,
#  '1002696': 2,
#  '1002706': 1,
#  '1002744': 5,
#  '1002749': 1,
#  '1002755': 1,
#  '1002756': 5,
#  '1002757': 2,
#  '1002760': 6,
#  '1002761': 1,
#  '1002765': 1,
#  '1002768': 1,
#  '1002771': 3,
#  '1002773': 1,
#  '1002783': 3,
#  '1002786': 3,
#  '1002787': 2,
#  '1002788': 4,
#  '1002790': 2,
#  '1002793': 2,
#  '1002796': 1,
#  '1002802': 3,
#  '1002804': 1,
#  '1002806': 1,
#  '1002807': 1,
#  '1002808': 1,
#  '1002809': 2,
#  '1002810': 1,
#  '1002811': 1,
#  '1002812': 2,
#  '1002814': 1,
#  '1002815': 1,
#  '1002816': 1,
#  '1002817': 1,
#  '1002818': 1,
#  '100282': 1,
#  '1002821': 2,
#  '1002822': 1,
#  '1002824': 1,
#  '1002826': 2,
#  '1002827': 1,
#  '1002828': 2,
#  '1002830': 3,
#  '1002831': 2,
#  '1002833': 1,
#  '1002834': 3,
#  '1002836': 2,
#  '1002837': 1,
#  '1002843': 1,
#  '1002846': 1,
#  '1002847': 1,
#  '1002848': 1,
#  '1002849': 2,
#  '100285': 1,
#  '1002850': 1,
#  '1002854': 1,
#  '1002855': 2,
#  '1002861': 3,
#  '1002862': 1,
#  '1002865': 1,
#  '1002870': 4,
#  '1002871': 4,
#  '1002872': 3,
#  '100288': 1,
#  '1002893': 4,
#  '1002894': 1,
#  '100290': 1,
#  '100291': 20,
#  '1002918': 1,
#  '1002919': 1,
#  '1002927': 2,
#  '100293': 1,
#  ...}

# %% [markdown]
# We are now ready to sort the lists so that the most common instance is the first element of the list.

# %%
# First element of the list will be the "main" instance of the artist
artists_lists = list(map(
    lambda artist_list: sorted(artist_list, key=lambda artist: artist_freqs.get(artist["id"], 0), reverse=True),
    artists_lists
))
artists_lists[:5]
# Out:
# [[{'id': '510355', 'name': 'Tom Salta'},
#   {'id': '510353', 'name': 'Atlas Plug'}],
#  [{'id': '515380', 'name': 'Sara Nicholas'},
#   {'id': '512604', 'name': 'DJ Ginger Snapp'}],
#  [{'id': '805193', 'name': 'Péter Takács'}, {'id': '182397', 'name': 'Deto'}],
#  [{'id': '1816108', 'name': 'Alex Bilowitz'},
#   {'id': '1303285', 'name': 'Alex Bilo'}],
#  [{'id': '258876', 'name': 'Lützenkirchen'},
#   {'id': '366859', 'name': 'Tobias Lützenkirchen'},
#   {'id': '134438', 'name': 'LXR'},
#   {'id': '690598', 'name': 'Paratopic'},
#   {'id': '408293', 'name': 'L.Y.T.Z.'},
#   {'id': '411300', 'name': 'Lu Tracks'},
#   {'id': '159973', 'name': 'Toby Lee Connor'},
#   {'id': '131031', 'name': 'Karosa'},
#   {'id': '121353', 'name': 'Richthoven'},
#   {'id': '165609', 'name': '7-7-0'}]]

# %% [markdown]
# So far we've only handled the "multiple instances" artists. The following block of code adds the "single instance" artists to the list. It doesn't matter if we do this after the sort, these lists are going to have only one instance of the artist after all.

# %%
# Has to be a better way to do this
# WARNING: ~3m execution time
for _, row in releases.iterrows():
    artists_in_row = (
        {
            "id": row[f"a{i}_id"],
            "name": row[f"a{i}_name"],
        }
        for i in range(5) if row[f"a{i}_id"] != ""
    )
    for artist in artists_in_row:
        if artist["id"] not in seen_dict:
            artists_lists.append([artist])
artists_lists[-5:]
# Out:
# [[{'id': '30462', 'name': 'Francis Poulenc'}],
#  [{'id': '1205355', 'name': 'Loota'}],
#  [{'id': '1205354', 'name': 'JayAllDay'}],
#  [{'id': '1129217', 'name': 'KOHH'}],
#  [{'id': '1033122', 'name': 'Okasian'}]]

# %% [markdown]
# At this point we have a list of lists, the following will transform what we have into a list of dictionaries, ready to be serialized.

# %%
artists = list()
for artists_list in artists_lists:
    current_artist = dict()
    current_artist["main_id"] = artists_list[0]["id"]
    current_artist["known_ids"] = [artist["id"] for artist in artists_list]
    current_artist["known_names"] = [artist["name"] for artist in artists_list]
    artists.append(current_artist)
artists[:5]
# Out:
# [{'main_id': '510355',
#   'known_ids': ['510355', '510353'],
#   'known_names': ['Tom Salta', 'Atlas Plug']},
#  {'main_id': '515380',
#   'known_ids': ['515380', '512604'],
#   'known_names': ['Sara Nicholas', 'DJ Ginger Snapp']},
#  {'main_id': '805193',
#   'known_ids': ['805193', '182397'],
#   'known_names': ['Péter Takács', 'Deto']},
#  {'main_id': '1816108',
#   'known_ids': ['1816108', '1303285'],
#   'known_names': ['Alex Bilowitz', 'Alex Bilo']},
#  {'main_id': '258876',
#   'known_ids': ['258876',
#    '366859',
#    '134438',
#    '690598',
#    '408293',
#    '411300',
#    '159973',
#    '131031',
#    '121353',
#    '165609'],
#   'known_names': ['Lützenkirchen',
#    'Tobias Lützenkirchen',
#    'LXR',
#    'Paratopic',
#    'L.Y.T.Z.',
#    'Lu Tracks',
#    'Toby Lee Connor',
#    'Karosa',
#    'Richthoven',
#    '7-7-0']}]

# %%
artists[-5:]
# Out:
# [{'main_id': '30462',
#   'known_ids': ['30462'],
#   'known_names': ['Francis Poulenc']},
#  {'main_id': '1205355', 'known_ids': ['1205355'], 'known_names': ['Loota']},
#  {'main_id': '1205354',
#   'known_ids': ['1205354'],
#   'known_names': ['JayAllDay']},
#  {'main_id': '1129217', 'known_ids': ['1129217'], 'known_names': ['KOHH']},
#  {'main_id': '1033122', 'known_ids': ['1033122'], 'known_names': ['Okasian']}]

# %% [markdown]
# The only thing left is to actually serialize what we have.

# %%
jsons = [json.dumps(artist, ensure_ascii=False) for artist in artists]
unique_jsons = list(set(jsons))

with open("artists.jsonl", "w", encoding="utf-8") as out_file:
    for unique_json in unique_jsons:
        out_file.write(unique_json + "\n")

# %%
# !wc -l artists.jsonl
# Out:
# 783597 artists.jsonl

# %% [markdown]
# We can now retrieve the data every time we want.

# %%
with open("artists.jsonl", "r", encoding="utf-8") as in_file:
    artist_data = [json.loads(line) for line in in_file]
print(artist_data[:5])
# Out:
# [{'main_id': '2121669', 'known_ids': ['2121669'], 'known_names': ['Nicholas Fairbank']}, {'main_id': '1110377', 'known_ids': ['1110377'], 'known_names': ["I've Lost"]}, {'main_id': '1169734', 'known_ids': ['1169734'], 'known_names': ['windy hill']}, {'main_id': '2323344', 'known_ids': ['2323344'], 'known_names': ['Aphangak']}, {'main_id': '60138', 'known_ids': ['60138'], 'known_names': ['Flat 6']}]

# %% [markdown]
# ## Relationships dataset
#
# The next step is to save the relationships between the artists in a CSV file. Let's start collecting the different relationships.

# %%
link_types = pd.read_sql_query("SELECT DISTINCT id FROM link_type  WHERE entity_type0 = 'artist' AND entity_type1 = 'artist'", engine)
relationships = pd.DataFrame({
    'id0': [],
    'name0': [],
    'id1': [],
    'name1': [],
    'relationship_type': [],
})
for link_type in filter(lambda lt: lt not in (108, 292, 1079), link_types.id):
    query =\
f"""
SELECT a0.id AS id0, a0.name AS name0, a1.id AS id1, a1.name AS name1, {link_type} AS relationship_type
FROM l_artist_artist laa
JOIN artist a0 ON a0.id = laa.entity0
JOIN artist a1 ON a1.id = laa.entity1
WHERE laa.link IN (
    SELECT id
    FROM link
    WHERE link_type = {link_type}
);
"""
    result = pd.read_sql_query(query, engine, dtype=str)
    if result.empty:
        continue
    relationships = pd.concat([relationships, result])
del result
relationships.drop_duplicates(inplace=True)
relationships
# Out:
#          id0                         name0      id1               name1  \
# 0     448102                    Xoel López   248824         Lovely Luna
# 1     359330                   Miley Cyrus   686291       Helping Haiti
# 2     129154                         Jay-J   472106      Jay-J & Macari
# 3     267439                 Andrew Macari   472106      Jay-J & Macari
# 4      77944                 Michael Bublé   686291       Helping Haiti
# ..       ...                           ...      ...                 ...
# 563  1237428                   Curb Cobain   236309         Kurt Cobain
# 564  2731567                         JELEE  2723888                橘ののか
# 565  1625587  Chor und Orchester Mantovani   210790           Mantovani
# 566      242         The Chemical Brothers     1468   The Dust Brothers
# 567  2733328             The Erogerigegege   217284  The Gerogerigegege
#
#     relationship_type
# 0                 102
# 1                 102
# 2                 102
# 3                 102
# 4                 102
# ..                ...
# 563               973
# 564               973
# 565               973
# 566               973
# 567               973
#
# [564242 rows x 5 columns]

# %% [markdown]
# Now we filter the relationships so that we don't have artists that don't concern us.

# %%
mask = relationships[["id0", "id1"]].isin(artist_freqs.keys()).all(axis=1)
filtered_relationships = relationships[mask]
filtered_relationships
# Out:
#          id0                  name0      id1                  name1  \
# 0     448102             Xoel López   248824            Lovely Luna
# 1     359330            Miley Cyrus   686291          Helping Haiti
# 2     129154                  Jay-J   472106         Jay-J & Macari
# 3     267439          Andrew Macari   472106         Jay-J & Macari
# 4      77944          Michael Bublé   686291          Helping Haiti
# ..       ...                    ...      ...                    ...
# 556  1004547             SpongeBOZZ    43102  SpongeBob SquarePants
# 557  2685255          Trio Messiaen    10371       Olivier Messiaen
# 558  2705719            GUNRINGER-Y  1603935           Gunslinger-R
# 563  1237428            Curb Cobain   236309            Kurt Cobain
# 566      242  The Chemical Brothers     1468      The Dust Brothers
#
#     relationship_type
# 0                 102
# 1                 102
# 2                 102
# 3                 102
# 4                 102
# ..                ...
# 556               973
# 557               973
# 558               973
# 563               973
# 566               973
#
# [125812 rows x 5 columns]

# %% [markdown]
# Now, we have the relationships, but we've made an artist dataset that will help in the task of replacing the non-important id with the main id for each artist. For this task a dictionary will be created.

# %%
changes_dict = dict()
for artist in artist_data:
    if len(artist["known_ids"]) > 1:
        for known_id in artist["known_ids"]:
            if known_id != artist["main_id"]:
                changes_dict[known_id] = artist["main_id"]
len(changes_dict)
# Out:
# 70660

# %% [markdown]
# These are the relationships that we need to modify.

# %%
mask = filtered_relationships[["id0", "id1"]].isin(changes_dict.keys()).any(axis=1)
filtered_relationships.loc[mask]
# Out:
#          id0                         name0      id1                  name1  \
# 122   426487    The Count of Monte Cristal   541571     The Count & Sinden
# 123   184688                   Frank Tovey   195090                Mkultra
# 127    57716  Filippo “Naughty” Moscatello   337131        Naughty & Tolis
# 160   239310               Sharon den Adel    54309              Avantasia
# 190   436287               Dominick Martin   595980                St. Cal
# ..       ...                           ...      ...                    ...
# 392  2281011                      KEN PLUS   923360         Macintosh Plus
# 402  2458694     fluttershy will never die  1162788             Fluttershy
# 456  2629185                          月見英子  2316189                   月見英子
# 556  1004547                    SpongeBOZZ    43102  SpongeBob SquarePants
# 558  2705719                   GUNRINGER-Y  1603935           Gunslinger-R
#
#     relationship_type
# 122               102
# 123               102
# 127               102
# 160               102
# 190               102
# ..                ...
# 392               973
# 402               973
# 456               973
# 556               973
# 558               973
#
# [4553 rows x 5 columns]

# %%
filtered_relationships.loc[mask, ["id0", "id1"]] = filtered_relationships.loc[mask, ["id0", "id1"]].replace(changes_dict)

filtered_relationships.loc[mask]
# Out:
#          id0                         name0      id1                  name1  \
# 122   344890    The Count of Monte Cristal   541571     The Count & Sinden
# 123    46990                   Frank Tovey   195090                Mkultra
# 127   117552  Filippo “Naughty” Moscatello   337131        Naughty & Tolis
# 160  1588050               Sharon den Adel    54309              Avantasia
# 190    71451               Dominick Martin   595980                St. Cal
# ..       ...                           ...      ...                    ...
# 392  2281011                      KEN PLUS   860871         Macintosh Plus
# 402  2458697     fluttershy will never die  1162788             Fluttershy
# 456  1577273                          月見英子  1423112                   月見英子
# 556  1700445                    SpongeBOZZ    43102  SpongeBob SquarePants
# 558  2595181                   GUNRINGER-Y   334571           Gunslinger-R
#
#     relationship_type
# 122               102
# 123               102
# 127               102
# 160               102
# 190               102
# ..                ...
# 392               973
# 402               973
# 456               973
# 556               973
# 558               973
#
# [4553 rows x 5 columns]

# %%
changes_dict["426487"]
# Out:
# '344890'

# %% [markdown]
# We can make sure that there are no cyclic references this way (hoping for a False return):

# %%
filtered_relationships[["id0", "id1"]].isin(changes_dict.keys()).any(axis=1).any()
# Out:
# False

# %% [markdown]
# Now we can finally save our relationships CSV.

# %%
filtered_relationships.to_csv("relationships.csv", index=False)

# %%
# !wc -l relationships.csv
# Out:
# 125813 relationships.csv

# %% [markdown]
# ## Releases dataset with main IDs
#
# Now that we're here, why not do the same with the releases dataset, which we have already in memory.

# %%
mask = releases[id_columns].isin(changes_dict.keys()).any(axis=1)
releases.loc[mask, id_columns]
# Out:
#            a0_id    a1_id    a2_id    a3_id    a4_id
# 457      2630975
# 813       604380
# 900      1875555
# 902      2119905
# 962      1400830
# ...          ...      ...      ...      ...      ...
# 2841284  2641987  2641986  2641985  2641984  1679364
# 2841297  2104904  2104903  2041481  1810635  1141182
# 2841349   741223   535356   352163   284443   180306
# 2841525  1181250   688686   469344   333071   137868
# 2841530  1455299   801401   605351   544897   379900
#
# [47645 rows x 5 columns]

# %%
# WARNING: ~10m execution time
releases.loc[mask, id_columns] = releases.loc[mask, id_columns].replace(changes_dict)

releases.loc[mask, id_columns]
# Out:
#            a0_id    a1_id    a2_id    a3_id    a4_id
# 457      1245245
# 813       284452
# 900      1875579
# 902       741269
# 962       531216
# ...          ...      ...      ...      ...      ...
# 2841284  2641987  1679364  2641984  2641984  1679364
# 2841297  1141182  1810635  2041481  1810635  1141182
# 2841349   741223   203282   158068   190601   180306
# 2841525   779144   688686   469344   333071   137868
# 2841530  1089631   801401   605351   544897   379900
#
# [47645 rows x 5 columns]

# %%
releases[id_columns].isin(changes_dict.keys()).any(axis=1).any()
# Out:
# False

# %%
releases.to_csv("releases_no_va_merged.csv", index=False)

# %%
# !wc -l releases_no_va_merged.csv
# Out:
# 2841557 releases_no_va_merged.csv

# %% [markdown]
# ## Cleanup

# %%
engine.dispose()
conn.close()

# %%
# !service postgresql stop
